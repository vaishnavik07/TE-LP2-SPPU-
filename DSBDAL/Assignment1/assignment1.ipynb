# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # Assignment 1 & 2 Code included

# %%
df=pd.read_csv("dataset.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 3                    none        47.0           57.0           44.0
# 4                    none        76.0           78.0           75.0

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# ...

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed        88.0           99.0           95.0
# 996                    none        62.0           55.0           55.0
# 997               completed        59.0           71.0           65.0
# 998               completed        68.0           78.0           77.0
# 999                    none        77.0           86.0           86.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   986 non-null    float64
#  6   reading score                986 non-null    float64
#  7   writing score                987 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  986.000000     986.000000     987.000000
# mean    66.045639      69.081136      68.125633
# std     15.196946      14.581593      15.232759
# min      0.000000      17.000000      10.000000
# 25%     57.000000      59.000000      58.000000
# 50%     66.000000      70.000000      69.000000
# 75%     77.000000      79.000000      79.000000
# max    100.000000     100.000000     100.000000

# %%
df.shape
# Out:
# (1000, 8)

# %%
df["math score"].value_counts()
# Out:
# math score
# 65.0    36
# 62.0    34
# 59.0    32
# 69.0    32
# 61.0    27
#         ..
# 28.0     1
# 18.0     1
# 0.0      1
# 22.0     1
# 8.0      1
# Name: count, Length: 81, dtype: int64

# %%
df.isnull().sum()
# Out:
# gender                          0
# race/ethnicity                  0
# parental level of education     0
# lunch                           0
# test preparation course         0
# math score                     14
# reading score                  14
# writing score                  13
# dtype: int64

# %%
li=['math score', 'reading score', 'writing score']
for i in li:
    df[i].fillna(df[i].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                     float64
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
df['math score']=df['math score'].astype('int32')

# %%
df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                       int32
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
new_gd= pd.get_dummies(df["gender"])
new_gd
# Out:
#      female   male
# 0      True  False
# 1      True  False
# 2      True  False
# 3     False   True
# 4     False   True
# ..      ...    ...
# 995    True  False
# 996   False   True
# 997    True  False
# 998    True  False
# 999    True  False
#
# [1000 rows x 2 columns]

# %%
df.drop(columns=["gender"], inplace=True)

# %%
df.shape
# Out:
# (1000, 7)

# %%
df=pd.concat([df, new_gd], axis=1)

# %%
df
# Out:
#     race/ethnicity parental level of education         lunch  \
# 0          group B           bachelor's degree      standard
# 1          group C                some college      standard
# 2          group B             master's degree      standard
# 3          group A          associate's degree  free/reduced
# 4          group C                some college      standard
# ..             ...                         ...           ...
# 995        group E             master's degree      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  female  \
# 0                      none          72           72.0           74.0    True
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l=LabelEncoder()
df['lunch']=l.fit_transform(df['lunch'])

# %%
df
# Out:
#     race/ethnicity parental level of education  lunch test preparation course  \
# 0          group B           bachelor's degree      1                    none
# 1          group C                some college      1               completed
# 2          group B             master's degree      1                    none
# 3          group A          associate's degree      0                    none
# 4          group C                some college      1                    none
# ..             ...                         ...    ...                     ...
# 995        group E             master's degree      1               completed
# 996        group C                 high school      0                    none
# 997        group C                 high school      0               completed
# 998        group D                some college      1               completed
# 999        group D                some college      0                    none
#
# ...

# %% [markdown]
# Min max scaling

# %%
df["math score"]=(df['math score']-df['math score'].min())/(df['math score'].max()-df['math score'].min())

# %%
df["math score"]
# Out:
# 0      0.72
# 1      0.69
# 2      0.90
# 3      0.47
# 4      0.76
#        ...
# 995    0.88
# 996    0.62
# 997    0.59
# 998    0.68
# 999    0.77
# Name: math score, Length: 1000, dtype: float64

# %% [markdown]
# Z-Score normalization

# %%
df['reading score']=(df['reading score']-df["reading score"].mean())/df['reading score'].std()
df
# Out:
#     race/ethnicity parental level of education  lunch test preparation course  \
# 0          group B           bachelor's degree      1                    none
# 1          group C                some college      1               completed
# 2          group B             master's degree      1                    none
# 3          group A          associate's degree      0                    none
# 4          group C                some college      1                    none
# ..             ...                         ...    ...                     ...
# 995        group E             master's degree      1               completed
# 996        group C                 high school      0                    none
# 997        group C                 high school      0               completed
# 998        group D                some college      1               completed
# 999        group D                some college      0                    none
#
# ...

# %% [markdown]
# Handle outliers using interquartile range

# %%
Q1= df['writing score'].quantile(0.25)
Q3= df['writing score'].quantile(0.75)

IQR=Q3-Q1

print(Q1)
print(Q3)
print(IQR)
# Out:
# 58.0
# 79.0
# 21.0

# %%
outlier_threshold=1.5*IQR
print(outlier_threshold)
# Out:
# 31.5

# %%
# Identify the outliers
outliers=df[(df['writing score']<Q1-outlier_threshold) | (df['writing score']>Q3+outlier_threshold)]
print(outliers)
# Out:
#     race/ethnicity parental level of education  lunch test preparation course  \
# 59         group C            some high school      0                    none
# 76         group E            some high school      1                    none
# 327        group A                some college      0                    none
# 596        group B                 high school      0                    none
# 980        group B                 high school      0                    none
#
#      math score  reading score  writing score  female   male
# 59         0.00      -3.596997           10.0    True  False
# 76         0.30      -2.975410           22.0   False   True
# 327        0.28      -3.182606           19.0   False   True
# 596        0.30      -3.113540           15.0   False   True
# 980        0.08      -3.113540           23.0    True  False

# %%
#Replace oulier values by boundary values  
df_transformed=df.copy()

df_transformed['writing score']=np.clip(df_transformed['writing score'], Q1-outlier_threshold, Q3+outlier_threshold)

# %%
outliers_rem=df_transformed[(df_transformed['writing score']<Q1-outlier_threshold) | (df_transformed['writing score']>Q3+outlier_threshold)]
outliers_rem
# Out:
# Empty DataFrame
# Columns: [race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score, female, male]
# Index: []

# %%
#Option 2: remove outliers

df_filtered=df[~((df['writing score']<Q1-outlier_threshold) | (df['writing score']>Q3+outlier_threshold))]
df_filtered
# Out:
#     race/ethnicity parental level of education  lunch test preparation course  \
# 0          group B           bachelor's degree      1                    none
# 1          group C                some college      1               completed
# 2          group B             master's degree      1                    none
# 3          group A          associate's degree      0                    none
# 4          group C                some college      1                    none
# ..             ...                         ...    ...                     ...
# 995        group E             master's degree      1               completed
# 996        group C                 high school      0                    none
# 997        group C                 high school      0               completed
# 998        group D                some college      1               completed
# 999        group D                some college      0                    none
#
# ...

# %%
df_filtered.shape
# Out:
# (995, 9)

# %% [markdown]
# Visualize outliers using boxplot

# %%
plt.figure()
plt.boxplot(df['math score'])
plt.title('Box plot of math score')
plt.show()
